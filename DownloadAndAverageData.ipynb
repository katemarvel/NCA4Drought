# %%
import cdms2 as cdms
import MV2 as MV
import cdtime,cdutil,genutil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import string
import glob
import scipy.stats as stats
# Local solution
# If running remotely, uncomment the following code:
# %%bash
# git clone https://github.com/katemarvel/CMIP5_tools
# import CMIP5_tools as cmip5
import sys,os
sys.path.append("/Users/kmarvel/Google Drive/python-utils")

import CMIP5_tools as cmip5
import DA_tools
import Plotting

from eofs.cdms import Eof
from eofs.multivariate.cdms import MultivariateEof
# %matplotlib inline

import requests
import pandas as pd

### Set classic Netcdf (ver 3)
cdms.setNetcdfShuffleFlag(0)
cdms.setNetcdfDeflateFlag(0)
cdms.setNetcdfDeflateLevelFlag(0)

external_drive='/Volumes/CMIP6/'

# %%
NCA4regions={}
#Northwest (NW): (125°W–111°W, 42°N–49°N)
NCA4regions["NW"]=cdutil.region.domain(longitude=(-125,-111),latitude=(42,49))
#Southwest (SW): (124°W–102°W, 31°N–42°N)
NCA4regions["SW"]=cdutil.region.domain(longitude=(-124,-102),latitude=(31,42))
#Upper Great Plains (GPu): (116°W–95°W, 40°N–49°N)
NCA4regions["GPu"]=cdutil.region.domain(longitude=(-116,-95),latitude=(40,49))
#Lower Great Plains (GPl): (107°W–93°W, 26°N–40°N)
NCA4regions["GPl"]=cdutil.region.domain(longitude=(-107,-93),latitude=(26,40))
#Midwest (MW): (97°W–80°W, 36°N–50°N)
NCA4regions["MW"]=cdutil.region.domain(longitude=(-97,-80),latitude=(36,50))
#Northeast (NE): (82°W–67°W, 37°N–48°N)
NCA4regions["NE"]=cdutil.region.domain(longitude=(-82,-67),latitude=(37,48))
#Southeast (SE): (95°W–76°W, 25°N–39°N)
NCA4regions["SE"]=cdutil.region.domain(longitude=(-95,-76),latitude=(25,39))

# %%
def pull_data(curr_mod,curr_var,experiment_id,member_id,overwrite=False):
    # Baseline directory
    base_dir   = 'http://mary.ldeo.columbia.edu:81/CMIP6/.'
    # Write directory
    
    base_write_dir= external_drive+'DROUGHT/DOWNLOADED_RAW/'
    df_proclist = pd.DataFrame(columns=['model','sim','ensemble','variable'])
    ingrid_cmip6 = pd.read_csv("mary_cmip6.csv")


    write_dir = base_write_dir+curr_var+"/"+curr_mod+"/"
    write_stem = curr_var+"."+experiment_id+"."+curr_mod+"."+member_id+".*.nc"
    
    #If the directory doesn't exist already, make it
    os.makedirs(os.path.join(base_write_dir, curr_var, curr_mod),exist_ok=True)
    
    if not overwrite:
        already_exist=glob.glob(write_dir+write_stem)
        if len(already_exist)!=0:
            return False
    #rips=np.unique(np.array(df1.member_id))

    df1 = ingrid_cmip6[(ingrid_cmip6.source_id==curr_mod)\
                                   & (ingrid_cmip6.variable_id==curr_var) & \
                                   (ingrid_cmip6.experiment_id == experiment_id)&\
                                  (ingrid_cmip6.member_id == member_id)]

    #Construct openDAP link
    nfiles,nidentifiers=df1.shape
    times=np.sort(np.array(df1.time_range))
    i_ens=np.where(df1.time_range==times[0])[0]
    time_range=times[0]

    for time_range in times:
        # Construct Remote OpenDAP Link
        i_ens=np.where(df1.time_range==time_range)[0][0]
        nc_link = base_dir+df1.activity_id.iloc[i_ens]+'/.'+df1.institution_id.iloc[i_ens]+'/.'+curr_mod+'/.'+experiment_id+'/.'+df1.member_id.iloc[i_ens]+'/.'+df1.table_id.iloc[i_ens]+ \
                            '/.'+curr_var+'/.'+df1.grid_label.iloc[i_ens]+'/.'+df1.version.iloc[i_ens]+'/.'+df1.file_basename.iloc[i_ens]+'/.'+curr_var+'/dods'
        request = requests.get(nc_link)
        if request.status_code == 200:
            #Get the data
            f=cdms.open(nc_link)
            data=f(curr_var)
            tax=data.getTime()
            tax.id="time"
            latax=data.getLatitude()
            lonax=data.getLongitude()
            #reshape it to years and months
            ntime=data.shape[0]
            nyears=int(ntime/12)
            rdata=data.reshape((nyears,12)+data.shape[1:])
            for i in range(nyears):
                yeardata=rdata[i]
                #Make the time axis
                tax_trunc=cdms.createAxis(tax[12*i:12*(i+1)])
                tax_trunc.designateTime()
                for key in tax.attributes.keys():
                    setattr(tax_trunc,key,tax.attributes[key])
                yeardata.setAxis(0,tax_trunc)
                yeardata.setAxis(1,latax)
                yeardata.setAxis(2,lonax)
                #get the start year for labeling purposes
                year=str(tax_trunc.asComponentTime()[0].year)
                writename = curr_var+"."+experiment_id+"."+curr_mod+"."+member_id+"."+year.zfill(4)+".nc"
                fw=cdms.open(write_dir+writename,"w")
                fw.write(yeardata)
                fw.close()
            f.close()
        return True

# %%
def check_availability(curr_mod,curr_var,experiment_id):
    ingrid_cmip6 = pd.read_csv("mary_cmip6.csv")
    df1 = ingrid_cmip6[(ingrid_cmip6.source_id==curr_mod)\
                       & (ingrid_cmip6.variable_id==curr_var)\
                       & (ingrid_cmip6.experiment_id == experiment_id)]
    return(df1)
def get_members(curr_mod,curr_var,experiment_id):
    df1=check_availability(curr_mod,curr_var,experiment_id)
    return(np.unique(df1.member_id))

# %%
def check_fixed_var_availability(curr_mod,fixed_var="sftlf",member_id="r1i1p1f1"):
    ingrid_cmip6 = pd.read_csv("mary_cmip6.csv")
    df1 = ingrid_cmip6[(ingrid_cmip6.source_id==curr_mod)\
                       & (ingrid_cmip6.variable_id==fixed_var)\
                       & (ingrid_cmip6.member_id == member_id)]
    return(df1)

# %%
def pull_fixedvar(curr_mod,curr_var,experiment_id,member_id,overwrite=False):

    # Baseline directory
    base_dir   = 'http://mary.ldeo.columbia.edu:81/CMIP6/.'
    # Write directory
    
    base_write_dir= external_drive+'DROUGHT/fixedvar/'
    df_proclist = pd.DataFrame(columns=['model','sim','ensemble','variable'])
    ingrid_cmip6 = pd.read_csv("mary_cmip6.csv")


    write_dir = base_write_dir
    write_stem=curr_var+"_fx_"+curr_mod+".nc"
    #write_stem = curr_var+"."+experiment_id+"."+curr_mod+"."+member_id+".*.nc"
    
   
    if not overwrite:
        already_exist=glob.glob(write_dir+write_stem)
        if len(already_exist)!=0:
            print("already exists")
            #return False
    #rips=np.unique(np.array(df1.member_id))

    df1 = ingrid_cmip6[(ingrid_cmip6.source_id==curr_mod)\
                                   & (ingrid_cmip6.variable_id==curr_var) & \
                                   (ingrid_cmip6.experiment_id == experiment_id)&\
                                  (ingrid_cmip6.member_id == member_id)]

    #Construct openDAP link
    nfiles,nidentifiers=df1.shape
    if nfiles==1:
        i_ens=0
        nc_link = base_dir+df1.activity_id.iloc[i_ens]+'/.'+df1.institution_id.iloc[i_ens]+'/.'+curr_mod+'/.'+experiment_id+'/.'+df1.member_id.iloc[i_ens]+'/.'+df1.table_id.iloc[i_ens]+ \
                            '/.'+curr_var+'/.'+df1.grid_label.iloc[i_ens]+'/.'+df1.version.iloc[i_ens]+'/.'+df1.file_basename.iloc[i_ens]+'/.'+curr_var+'/dods'
        request = requests.get(nc_link)
        if request.status_code == 200:
            #Get the data
            f=cdms.open(nc_link)
            data=f(curr_var)
            fw=cdms.open(write_dir+write_stem,"w")
            fw.write(data)
            fw.close()
    else:
        print("more than one candidate found")
        print(df1)

# %%
def pull_land_fractions():
    models=[x.split("/")[-1] for x in glob.glob(external_drive+"DROUGHT/DOWNLOADED_RAW/tas/*")]
    already_done=[x.split("_fx_")[-1].split(".")[0] for x in glob.glob(external_drive+"DROUGHT/fixedvar/sftlf*")]
    not_yet=np.setdiff1d(models,already_done)


    for model in not_yet:
        print(model)
      #  print(len(check_fixed_var_availability(model)))

        if "piControl" in np.array(check_fixed_var_availability(model).experiment_id):
            pull_fixedvar(model,"sftlf","piControl","r1i1p1f1")
        elif "amip" in np.array(check_fixed_var_availability(model).experiment_id):
            pull_fixedvar(model,"sftlf","amip","r1i1p1f1")
        else:
            print("nothing found for ",model)

# %%
def download_hydrological_data(variables,experiments,models=None):
    ingrid_cmip6 = pd.read_csv("mary_cmip6.csv")
    if models is None:
        models=np.unique(ingrid_cmip6.source_id)
    for experiment_id in experiments:
        for variable in variables:
            for model in models:
                rips=get_members(model,variable,experiment_id)
                for rip in rips:
                    try:
                        downloaded=pull_data(model,variable,experiment_id,rip)
                        if downloaded:
                            print("model: ",model)
                            print("variable: ",variable)
                            print("experiment: ",experiment)
                            print("rip: ",rip)
                    except: print(variable+" and "+ model +" are bad")


def NCA4_regions_average(variables,experiments,overwrite=False):

    datadirec=external_drive+"DROUGHT/DOWNLOADED_RAW/"
    writedirec=external_drive+"DROUGHT/NCA4/"
    fixedvardirec=external_drive+"DROUGHT/fixedvar/"



    ###### LOOP OVER ALL VARIABLES #####
    for variable in variables:

        for region in NCA4regions.keys():
            cmd = "mkdir "+writedirec+"/"+region+"/"+variable
            os.system(cmd)


        
        modeldirs=glob.glob(datadirec+variable+"/*")
        ### LOOP OVER ALL MODELS
        for direc in modeldirs:
            model=direc.split("/")[-1]
            
            allfiles=glob.glob(direc+"/*"+variable+"*")
            

            ###### LOOP OVER ALL EXPERIMENTS #####
            for experiment in experiments:
                writedirecs={}
                for region in NCA4regions.keys():
                
                    region_writedirec=writedirec+region+"/"+variable+"/"+experiment+"/"
                    cmd="mkdir "+region_writedirec
                    os.system(cmd)
                    writedirecs[region]=region_writedirec

                allfiles_experiment=glob.glob(direc+"/"+variable+"."+experiment+".*")
                rips=np.unique([x.split(".")[-3] for x in allfiles_experiment])

                landthresh=1
                #Get the land fraction
                landfiles=glob.glob(fixedvardirec+"sftlf*"+model+".*")


                if len(landfiles)==1:
                    fland=cdms.open(landfiles[0])
                    landfrac=fland("sftlf")
                    fland.close()
                else:
                    print("can't find land fraction file for", model)
                    print(landfiles)
                    continue
                #print(direc)



                ###### LOOP OVER ALL RIPS #####
                for rip in rips:
                    #print(rip)
                    writenames={}
                    for key in NCA4regions.keys():
                        writename=writedirecs[key]+variable+"."+experiment+"."+model+"."+rip+".nc"

                        writenames[key]=writename

                    yearcheck=[]
                    
                    ripfiles=np.sort(glob.glob(direc+"/"+variable+"."+experiment+"."+model+"."+rip+"*"))
                    
                    L=len(ripfiles)
                    i=0
                    ripfile=ripfiles[i]
                    frip=cdms.open(ripfile)
                    data=frip(variable)
                    frip.close()
                    if data.shape[1:]!=landfrac.shape:
                        print("land mask wrong shape for "+variable+"."+experiment+"."+model+"."+rip)
                        continue
                    latax=landfrac.getLatitude()
                    lonax=landfrac.getLongitude()
                    tax=np.arange(12)
                    fpath,fexpt,fmodel,frip,fyear,fnc=ripfile.split(".")
                    ###Loop over regions
                    for key in NCA4regions.keys():
                        if writenames[key] in glob.glob(writedirecs[key]+"*"):
                            if not overwrite:
                                continue
                        if key=="NW":
                            print(variable+"."+experiment+"."+model+"."+rip+"*")
                        region=NCA4regions[key]
                        DATA=MV.zeros(L*12)
                        
                        landdata=cmip5.cdms_clone(np.repeat(.01*landfrac.asma()[np.newaxis],12,axis=0)*data,data)
                        landdata.setAxis(1,latax)
                        landdata.setAxis(2,lonax)
                       

                       
                        for i in range(L):

                            ripfile=ripfiles[i]

                            f=cdms.open(ripfile)
                            data=f(variable)

                           
                            landdata=cmip5.cdms_clone(np.repeat(.01*landfrac.asma()[np.newaxis],12,axis=0)*data,data)
                            #Kludge since downloading process didn't preserve lat/lon designation
                            landdata.setAxis(1,latax)
                            landdata.setAxis(2,lonax)
                            f.close()

                            fpath,fexpt,fmodel,frip,fyear,fnc=ripfile.split(".")
                            DATA[12*i:12*(i+1)]=cdutil.averager(landdata(region),axis='xy')
      
      
                            yearcheck+=[float(fyear)]
                        tax=cdms.createAxis(np.arange(L*12))
                        tax.designateTime()
                        tax.units='months since '+str(yearcheck[0])+'-1-1'
                        if variable in ["pr","prsn","mrros","mrro","evspsbl"]:
                            DATA=DATA*60*60*24 #convert to mm day-1
                            DATA.units="mm day -1"
                        else:
                            DATA.units="kg m-2"
                        DATA.setAxis(0,tax)
                        DATA.id=variable
                        fw=cdms.open(writenames[key],"w")
                        fw.write(DATA)
                        fw.close()
                        #if key == "SE":
                            #print(variable+"."+experiment+"."+model+"."+rip+"*")

# %%
variables=['tas', 'mrro', 'mrros', 'mrso','mrsos', 'pr', 'evspsbl', 'prsn']
experiments=["piControl","historical","ssp126","ssp585","ssp370","ssp245"]
experiments=["ssp126","ssp585","ssp370","ssp245"]

download_hydrological_data(variables,experiments)
# Out:
# /Users/kmarvel/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/numpy/ma/core.py:3174: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dout = self.data[indx]
# model:  ACCESS-CM2
# variable:  tas
# tas and ACCESS-CM2 are bad
# model:  ACCESS-ESM1-5
# variable:  tas
# tas and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  tas
# tas and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  tas
# tas and ACCESS-ESM1-5 are bad
# model:  AWI-CM-1-1-MR
# variable:  tas
# tas and AWI-CM-1-1-MR are bad
# model:  BCC-CSM2-MR
# variable:  tas
# tas and BCC-CSM2-MR are bad
# model:  CAMS-CSM1-0
# variable:  tas
# tas and CAMS-CSM1-0 are bad
# model:  CAMS-CSM1-0
# variable:  tas
# tas and CAMS-CSM1-0 are bad
# model:  CESM2
# variable:  tas
# tas and CESM2 are bad
# model:  CESM2
# variable:  tas
# tas and CESM2 are bad
# model:  CESM2-WACCM
# variable:  tas
# tas and CESM2-WACCM are bad
# model:  CIESM
# variable:  tas
# tas and CIESM are bad
# model:  CNRM-CM6-1
# variable:  tas
# tas and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  tas
# tas and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  tas
# tas and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  tas
# tas and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  tas
# tas and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  tas
# tas and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1-HR
# variable:  tas
# tas and CNRM-CM6-1-HR are bad
# model:  CNRM-ESM2-1
# variable:  tas
# tas and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  tas
# tas and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  tas
# tas and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  tas
# tas and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  tas
# tas and CNRM-ESM2-1 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5
# variable:  tas
# tas and CanESM5 are bad
# model:  CanESM5-CanOE
# variable:  tas
# tas and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  tas
# tas and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  tas
# tas and CanESM5-CanOE are bad
# model:  EC-Earth3
# variable:  tas
# tas and EC-Earth3 are bad
# model:  EC-Earth3-Veg
# variable:  tas
# tas and EC-Earth3-Veg are bad
# model:  EC-Earth3-Veg
# variable:  tas
# tas and EC-Earth3-Veg are bad
# model:  EC-Earth3-Veg
# variable:  tas
# tas and EC-Earth3-Veg are bad
# model:  EC-Earth3-Veg
# variable:  tas
# tas and EC-Earth3-Veg are bad
# model:  FGOALS-f3-L
# variable:  tas
# tas and FGOALS-f3-L are bad
# /Users/kmarvel/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/cdms2/axis.py:1685: UserWarning:
# Your first bounds[0,0] -1.000000000000000 will be corrected to -1.000000000000000
# Your bounds bounds[-1,1] 359.000000000000000 will be corrected to 359.000000000000000
#   warnings.warn(msg, UserWarning)
# model:  FGOALS-g3
# variable:  tas
# tas and FGOALS-g3 are bad
# model:  FIO-ESM-2-0
# variable:  tas
# tas and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  tas
# tas and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  tas
# tas and FIO-ESM-2-0 are bad
# model:  GFDL-ESM4
# variable:  tas
# tas and GFDL-ESM4 are bad
# model:  GISS-E2-1-G
# variable:  tas
# tas and GISS-E2-1-G are bad
# model:  GISS-E2-1-G
# variable:  tas
# tas and GISS-E2-1-G are bad
# model:  HadGEM3-GC31-LL
# variable:  tas
# tas and HadGEM3-GC31-LL are bad
# model:  INM-CM4-8
# variable:  tas
# tas and INM-CM4-8 are bad
# model:  INM-CM5-0
# variable:  tas
# tas and INM-CM5-0 are bad
# model:  IPSL-CM6A-LR
# variable:  tas
# tas and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  tas
# tas and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  tas
# tas and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  tas
# tas and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  tas
# tas and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  tas
# tas and IPSL-CM6A-LR are bad
# model:  KACE-1-0-G
# variable:  tas
# tas and KACE-1-0-G are bad
# model:  KACE-1-0-G
# variable:  tas
# tas and KACE-1-0-G are bad
# model:  KACE-1-0-G
# variable:  tas
# tas and KACE-1-0-G are bad
# model:  MCM-UA-1-0
# variable:  tas
# tas and MCM-UA-1-0 are bad
# model:  MIROC-ES2L
# variable:  tas
# tas and MIROC-ES2L are bad
# model:  MIROC-ES2L
# variable:  tas
# tas and MIROC-ES2L are bad
# model:  MIROC-ES2L
# variable:  tas
# tas and MIROC-ES2L are bad
# model:  MIROC6
# variable:  tas
# tas and MIROC6 are bad
# model:  MIROC6
# variable:  tas
# tas and MIROC6 are bad
# model:  MIROC6
# variable:  tas
# tas and MIROC6 are bad
# model:  MPI-ESM1-2-HR
# variable:  tas
# tas and MPI-ESM1-2-HR are bad
# model:  MPI-ESM1-2-HR
# variable:  tas
# tas and MPI-ESM1-2-HR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MPI-ESM1-2-LR
# variable:  tas
# tas and MPI-ESM1-2-LR are bad
# model:  MRI-ESM2-0
# variable:  tas
# tas and MRI-ESM2-0 are bad
# model:  NESM3
# variable:  tas
# tas and NESM3 are bad
# model:  NESM3
# variable:  tas
# tas and NESM3 are bad
# model:  NorESM2-LM
# variable:  tas
# tas and NorESM2-LM are bad
# model:  NorESM2-MM
# variable:  tas
# tas and NorESM2-MM are bad
# model:  UKESM1-0-LL
# variable:  tas
# tas and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  tas
# tas and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  tas
# tas and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  tas
# tas and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  tas
# tas and UKESM1-0-LL are bad
# /Users/kmarvel/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/numpy/ma/core.py:3206: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   mout = _mask[indx]
# model:  ACCESS-CM2
# variable:  mrro
# mrro and ACCESS-CM2 are bad
# model:  ACCESS-ESM1-5
# variable:  mrro
# mrro and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrro
# mrro and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrro
# mrro and ACCESS-ESM1-5 are bad
# model:  BCC-CSM2-MR
# variable:  mrro
# mrro and BCC-CSM2-MR are bad
# model:  CAMS-CSM1-0
# variable:  mrro
# mrro and CAMS-CSM1-0 are bad
# model:  CESM2
# variable:  mrro
# mrro and CESM2 are bad
# model:  CESM2
# variable:  mrro
# mrro and CESM2 are bad
# model:  CESM2-WACCM
# variable:  mrro
# mrro and CESM2-WACCM are bad
# model:  CNRM-CM6-1
# variable:  mrro
# mrro and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrro
# mrro and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrro
# mrro and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrro
# mrro and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrro
# mrro and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrro
# mrro and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1-HR
# variable:  mrro
# mrro and CNRM-CM6-1-HR are bad
# model:  CNRM-ESM2-1
# variable:  mrro
# mrro and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrro
# mrro and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrro
# mrro and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrro
# mrro and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrro
# mrro and CNRM-ESM2-1 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5
# variable:  mrro
# mrro and CanESM5 are bad
# model:  CanESM5-CanOE
# variable:  mrro
# mrro and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrro
# mrro and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrro
# mrro and CanESM5-CanOE are bad
# model:  EC-Earth3
# variable:  mrro
# mrro and EC-Earth3 are bad
# model:  EC-Earth3-Veg
# variable:  mrro
# mrro and EC-Earth3-Veg are bad
# model:  EC-Earth3-Veg
# variable:  mrro
# mrro and EC-Earth3-Veg are bad
# model:  FGOALS-f3-L
# variable:  mrro
# mrro and FGOALS-f3-L are bad
# model:  FIO-ESM-2-0
# variable:  mrro
# mrro and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  mrro
# mrro and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  mrro
# mrro and FIO-ESM-2-0 are bad
# model:  GFDL-ESM4
# variable:  mrro
# mrro and GFDL-ESM4 are bad
# model:  INM-CM4-8
# variable:  mrro
# mrro and INM-CM4-8 are bad
# model:  INM-CM5-0
# variable:  mrro
# mrro and INM-CM5-0 are bad
# model:  IPSL-CM6A-LR
# variable:  mrro
# mrro and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrro
# mrro and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrro
# mrro and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrro
# mrro and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrro
# mrro and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrro
# mrro and IPSL-CM6A-LR are bad
# model:  KACE-1-0-G
# variable:  mrro
# mrro and KACE-1-0-G are bad
# model:  KACE-1-0-G
# variable:  mrro
# mrro and KACE-1-0-G are bad
# model:  MCM-UA-1-0
# variable:  mrro
# mrro and MCM-UA-1-0 are bad
# model:  MIROC-ES2L
# variable:  mrro
# mrro and MIROC-ES2L are bad
# model:  MIROC6
# variable:  mrro
# mrro and MIROC6 are bad
# model:  MIROC6
# variable:  mrro
# mrro and MIROC6 are bad
# model:  MIROC6
# variable:  mrro
# mrro and MIROC6 are bad
# model:  MPI-ESM1-2-HR
# variable:  mrro
# mrro and MPI-ESM1-2-HR are bad
# model:  MPI-ESM1-2-HR
# variable:  mrro
# mrro and MPI-ESM1-2-HR are bad
# model:  MRI-ESM2-0
# variable:  mrro
# mrro and MRI-ESM2-0 are bad
# model:  UKESM1-0-LL
# variable:  mrro
# mrro and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrro
# mrro and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrro
# mrro and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrro
# mrro and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrro
# mrro and UKESM1-0-LL are bad
# model:  ACCESS-CM2
# variable:  mrros
# mrros and ACCESS-CM2 are bad
# model:  ACCESS-ESM1-5
# variable:  mrros
# mrros and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrros
# mrros and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrros
# mrros and ACCESS-ESM1-5 are bad
# model:  BCC-CSM2-MR
# variable:  mrros
# mrros and BCC-CSM2-MR are bad
# model:  CAMS-CSM1-0
# variable:  mrros
# mrros and CAMS-CSM1-0 are bad
# model:  CESM2
# variable:  mrros
# mrros and CESM2 are bad
# model:  CESM2
# variable:  mrros
# mrros and CESM2 are bad
# model:  CESM2-WACCM
# variable:  mrros
# mrros and CESM2-WACCM are bad
# model:  CNRM-CM6-1
# variable:  mrros
# mrros and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrros
# mrros and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrros
# mrros and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrros
# mrros and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrros
# mrros and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrros
# mrros and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1-HR
# variable:  mrros
# mrros and CNRM-CM6-1-HR are bad
# model:  CNRM-ESM2-1
# variable:  mrros
# mrros and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrros
# mrros and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrros
# mrros and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrros
# mrros and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrros
# mrros and CNRM-ESM2-1 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5
# variable:  mrros
# mrros and CanESM5 are bad
# model:  CanESM5-CanOE
# variable:  mrros
# mrros and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrros
# mrros and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrros
# mrros and CanESM5-CanOE are bad
# model:  EC-Earth3
# variable:  mrros
# mrros and EC-Earth3 are bad
# mrros and EC-Earth3-Veg are bad
# model:  EC-Earth3-Veg
# variable:  mrros
# mrros and EC-Earth3-Veg are bad
# model:  FGOALS-f3-L
# variable:  mrros
# mrros and FGOALS-f3-L are bad
# model:  FGOALS-g3
# variable:  mrros
# mrros and FGOALS-g3 are bad
# model:  FIO-ESM-2-0
# variable:  mrros
# mrros and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  mrros
# mrros and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  mrros
# mrros and FIO-ESM-2-0 are bad
# model:  GFDL-ESM4
# variable:  mrros
# mrros and GFDL-ESM4 are bad
# model:  INM-CM4-8
# variable:  mrros
# mrros and INM-CM4-8 are bad
# model:  INM-CM5-0
# variable:  mrros
# mrros and INM-CM5-0 are bad
# model:  IPSL-CM6A-LR
# variable:  mrros
# mrros and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrros
# mrros and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrros
# mrros and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrros
# mrros and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrros
# mrros and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrros
# mrros and IPSL-CM6A-LR are bad
# model:  KACE-1-0-G
# variable:  mrros
# mrros and KACE-1-0-G are bad
# model:  KACE-1-0-G
# variable:  mrros
# mrros and KACE-1-0-G are bad
# model:  MCM-UA-1-0
# variable:  mrros
# mrros and MCM-UA-1-0 are bad
# model:  MIROC-ES2L
# variable:  mrros
# mrros and MIROC-ES2L are bad
# model:  MIROC6
# variable:  mrros
# mrros and MIROC6 are bad
# model:  MIROC6
# variable:  mrros
# mrros and MIROC6 are bad
# model:  MIROC6
# variable:  mrros
# mrros and MIROC6 are bad
# model:  MPI-ESM1-2-HR
# variable:  mrros
# mrros and MPI-ESM1-2-HR are bad
# model:  MPI-ESM1-2-HR
# variable:  mrros
# mrros and MPI-ESM1-2-HR are bad
# model:  MRI-ESM2-0
# variable:  mrros
# mrros and MRI-ESM2-0 are bad
# model:  UKESM1-0-LL
# variable:  mrros
# mrros and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrros
# mrros and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrros
# mrros and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrros
# mrros and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrros
# mrros and UKESM1-0-LL are bad
# model:  ACCESS-CM2
# variable:  mrso
# mrso and ACCESS-CM2 are bad
# model:  ACCESS-ESM1-5
# variable:  mrso
# mrso and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrso
# mrso and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrso
# mrso and ACCESS-ESM1-5 are bad
# model:  BCC-CSM2-MR
# variable:  mrso
# mrso and BCC-CSM2-MR are bad
# model:  CAMS-CSM1-0
# variable:  mrso
# mrso and CAMS-CSM1-0 are bad
# model:  CESM2
# variable:  mrso
# mrso and CESM2 are bad
# model:  CESM2
# variable:  mrso
# mrso and CESM2 are bad
# model:  CESM2-WACCM
# variable:  mrso
# mrso and CESM2-WACCM are bad
# model:  CNRM-CM6-1
# variable:  mrso
# mrso and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrso
# mrso and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrso
# mrso and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrso
# mrso and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrso
# mrso and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrso
# mrso and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1-HR
# variable:  mrso
# mrso and CNRM-CM6-1-HR are bad
# model:  CNRM-ESM2-1
# variable:  mrso
# mrso and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrso
# mrso and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrso
# mrso and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrso
# mrso and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrso
# mrso and CNRM-ESM2-1 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5
# variable:  mrso
# mrso and CanESM5 are bad
# model:  CanESM5-CanOE
# variable:  mrso
# mrso and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrso
# mrso and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrso
# mrso and CanESM5-CanOE are bad
# model:  EC-Earth3
# variable:  mrso
# mrso and EC-Earth3 are bad
# model:  EC-Earth3-Veg
# variable:  mrso
# mrso and EC-Earth3-Veg are bad
# model:  EC-Earth3-Veg
# variable:  mrso
# mrso and EC-Earth3-Veg are bad
# model:  FGOALS-f3-L
# variable:  mrso
# mrso and FGOALS-f3-L are bad
# model:  GFDL-ESM4
# variable:  mrso
# mrso and GFDL-ESM4 are bad
# model:  INM-CM4-8
# variable:  mrso
# mrso and INM-CM4-8 are bad
# model:  INM-CM5-0
# variable:  mrso
# mrso and INM-CM5-0 are bad
# model:  IPSL-CM6A-LR
# variable:  mrso
# mrso and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrso
# mrso and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrso
# mrso and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrso
# mrso and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrso
# mrso and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrso
# mrso and IPSL-CM6A-LR are bad
# model:  MCM-UA-1-0
# variable:  mrso
# mrso and MCM-UA-1-0 are bad
# model:  MIROC-ES2L
# variable:  mrso
# mrso and MIROC-ES2L are bad
# model:  MIROC6
# variable:  mrso
# mrso and MIROC6 are bad
# model:  MIROC6
# variable:  mrso
# mrso and MIROC6 are bad
# model:  MIROC6
# variable:  mrso
# mrso and MIROC6 are bad
# model:  MPI-ESM1-2-HR
# variable:  mrso
# mrso and MPI-ESM1-2-HR are bad
# model:  MPI-ESM1-2-HR
# variable:  mrso
# mrso and MPI-ESM1-2-HR are bad
# model:  MRI-ESM2-0
# variable:  mrso
# mrso and MRI-ESM2-0 are bad
# model:  UKESM1-0-LL
# variable:  mrso
# mrso and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrso
# mrso and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrso
# mrso and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrso
# mrso and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrso
# mrso and UKESM1-0-LL are bad
# model:  ACCESS-CM2
# variable:  mrsos
# mrsos and ACCESS-CM2 are bad
# model:  ACCESS-ESM1-5
# variable:  mrsos
# mrsos and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrsos
# mrsos and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  mrsos
# mrsos and ACCESS-ESM1-5 are bad
# model:  BCC-CSM2-MR
# variable:  mrsos
# mrsos and BCC-CSM2-MR are bad
# model:  CAMS-CSM1-0
# variable:  mrsos
# mrsos and CAMS-CSM1-0 are bad
# model:  CESM2
# variable:  mrsos
# mrsos and CESM2 are bad
# model:  CESM2
# variable:  mrsos
# mrsos and CESM2 are bad
# model:  CESM2-WACCM
# variable:  mrsos
# mrsos and CESM2-WACCM are bad
# model:  CNRM-CM6-1
# variable:  mrsos
# mrsos and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrsos
# mrsos and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrsos
# mrsos and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrsos
# mrsos and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrsos
# mrsos and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1
# variable:  mrsos
# mrsos and CNRM-CM6-1 are bad
# model:  CNRM-CM6-1-HR
# variable:  mrsos
# mrsos and CNRM-CM6-1-HR are bad
# model:  CNRM-ESM2-1
# variable:  mrsos
# mrsos and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrsos
# mrsos and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrsos
# mrsos and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrsos
# mrsos and CNRM-ESM2-1 are bad
# model:  CNRM-ESM2-1
# variable:  mrsos
# mrsos and CNRM-ESM2-1 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5
# variable:  mrsos
# mrsos and CanESM5 are bad
# model:  CanESM5-CanOE
# variable:  mrsos
# mrsos and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrsos
# mrsos and CanESM5-CanOE are bad
# model:  CanESM5-CanOE
# variable:  mrsos
# mrsos and CanESM5-CanOE are bad
# model:  EC-Earth3
# variable:  mrsos
# mrsos and EC-Earth3 are bad
# model:  EC-Earth3-Veg
# variable:  mrsos
# mrsos and EC-Earth3-Veg are bad
# model:  EC-Earth3-Veg
# variable:  mrsos
# mrsos and EC-Earth3-Veg are bad
# model:  FGOALS-f3-L
# variable:  mrsos
# mrsos and FGOALS-f3-L are bad
# model:  FGOALS-g3
# variable:  mrsos
# mrsos and FGOALS-g3 are bad
# model:  FIO-ESM-2-0
# variable:  mrsos
# mrsos and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  mrsos
# mrsos and FIO-ESM-2-0 are bad
# model:  FIO-ESM-2-0
# variable:  mrsos
# mrsos and FIO-ESM-2-0 are bad
# model:  GFDL-ESM4
# variable:  mrsos
# mrsos and GFDL-ESM4 are bad
# model:  IPSL-CM6A-LR
# variable:  mrsos
# mrsos and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrsos
# mrsos and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrsos
# mrsos and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrsos
# mrsos and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrsos
# mrsos and IPSL-CM6A-LR are bad
# model:  IPSL-CM6A-LR
# variable:  mrsos
# mrsos and IPSL-CM6A-LR are bad
# model:  KACE-1-0-G
# variable:  mrsos
# mrsos and KACE-1-0-G are bad
# model:  KACE-1-0-G
# variable:  mrsos
# mrsos and KACE-1-0-G are bad
# model:  MIROC-ES2L
# variable:  mrsos
# mrsos and MIROC-ES2L are bad
# model:  MIROC6
# variable:  mrsos
# mrsos and MIROC6 are bad
# model:  MIROC6
# variable:  mrsos
# mrsos and MIROC6 are bad
# model:  MIROC6
# variable:  mrsos
# mrsos and MIROC6 are bad
# model:  MPI-ESM1-2-HR
# variable:  mrsos
# mrsos and MPI-ESM1-2-HR are bad
# model:  MPI-ESM1-2-HR
# variable:  mrsos
# mrsos and MPI-ESM1-2-HR are bad
# model:  MRI-ESM2-0
# variable:  mrsos
# mrsos and MRI-ESM2-0 are bad
# model:  UKESM1-0-LL
# variable:  mrsos
# mrsos and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrsos
# mrsos and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrsos
# mrsos and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrsos
# mrsos and UKESM1-0-LL are bad
# model:  UKESM1-0-LL
# variable:  mrsos
# mrsos and UKESM1-0-LL are bad
# model:  ACCESS-CM2
# variable:  pr
# pr and ACCESS-CM2 are bad
# model:  ACCESS-ESM1-5
# variable:  pr
# pr and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  pr
# pr and ACCESS-ESM1-5 are bad
# model:  ACCESS-ESM1-5
# variable:  pr
# pr and ACCESS-ESM1-5 are bad
# model:  AWI-CM-1-1-MR
# variable:  pr
# pr and AWI-CM-1-1-MR are bad
# model:  BCC-CSM2-MR
# variable:  pr
# pr and BCC-CSM2-MR are bad
# model:  CAMS-CSM1-0
# variable:  pr
# pr and CAMS-CSM1-0 are bad
# model:  CAMS-CSM1-0
# variable:  pr
# pr and CAMS-CSM1-0 are bad
# model:  CESM2
# variable:  pr
# pr and CESM2 are bad
# model:  CESM2
# variable:  pr
# pr and CESM2 are bad
# model:  CESM2-WACCM
# variable:  pr
# pr and CESM2-WACCM are bad
# model:  CIESM
# variable:  pr
# pr and CIESM are bad

# %%
#allvariables=['tas', 'mrro', 'mrros', 'mrso', 'pr', 'evspsbl', 'prsn']
#allvariables=["evspsbl","prsn","mrsos"]e 
allvariables=["tran"]
allexperiments=["piControl","historical","ssp126","ssp585","ssp370","ssp245"]
NCA4_regions_average(allvariables,allexperiments)
# Out:
# can't find land fraction file for CAMS-CSM1-0
# []
# can't find land fraction file for CAMS-CSM1-0
# []
# can't find land fraction file for CAMS-CSM1-0
# []
# can't find land fraction file for CAMS-CSM1-0
# []
# can't find land fraction file for CAMS-CSM1-0
# []
# can't find land fraction file for CAMS-CSM1-0
# []
# can't find land fraction file for CanESM5-CanOE
# []
# can't find land fraction file for CanESM5-CanOE
# []
# can't find land fraction file for CanESM5-CanOE
# []
# can't find land fraction file for CanESM5-CanOE
# []
# can't find land fraction file for CanESM5-CanOE
# []
# can't find land fraction file for CanESM5-CanOE
# []
# can't find land fraction file for CNRM-CM6-1-HR
# []
# can't find land fraction file for CNRM-CM6-1-HR
# []
# can't find land fraction file for CNRM-CM6-1-HR
# []
# can't find land fraction file for CNRM-CM6-1-HR
# []
# can't find land fraction file for CNRM-CM6-1-HR
# []
# can't find land fraction file for CNRM-CM6-1-HR
# []
# tran.piControl.CNRM-ESM2-1.r1i1p1f2*
# /Users/kmarvel/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/numpy/ma/core.py:3174: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dout = self.data[indx]
# /Users/kmarvel/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/numpy/ma/core.py:3206: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   mout = _mask[indx]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-907acdecb696> in <module>
#       3 allvariables=["tran"]
#       4 allexperiments=["piControl","historical","ssp126","ssp585","ssp370","ssp245"]
# ----> 5 NCA4_regions_average(allvariables,allexperiments)
#
# <ipython-input-8-bcb091a02134> in NCA4_regions_average(variables, experiments, overwrite)
#     120
#     121                             f=cdms.open(ripfile)
# --> 122                             data=f(variable)
#     123
#     124
#
# ~/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/cdms2/cudsinterface.py in __call__(self, id, *args, **kwargs)
#      32             except (AttributeError, TypeError):
#      33                 raise CDMSError("No such variable, " + id)
# ---> 34         return v(*args, **kwargs)
#      35
#      36     def __getitem__(self, key):
#
# ~/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/cdms2/avariable.py in __call__(self, *args, **kwargs)
#     206                                    squeeze=squeeze,
#     207                                    order=order,
# --> 208                                    grid=grid)
#     209
#     210     select = __call__
#
# ~/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/cdms2/selectors.py in unmodified_select(self, variable, raw, squeeze, order, grid)
#     209             # result is variable when there are no components, for example.
#     210             return result.subRegion(squeeze=squeeze, order=order,
# --> 211                                     grid=grid, raw=raw)
#     212         else:
#     213             return result
#
# ~/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/cdms2/avariable.py in subRegion(self, *specs, **keys)
#     997                  'grid': grid,
#     998                  }
# --> 999             return self.subSlice(*slicelist, **d)
#    1000
#    1001         #
#
# ~/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/cdms2/avariable.py in subSlice(self, *specs, **keys)
#     749             singles = None
#     750         slicelist = self.specs2slices(speclist, force=1)
# --> 751         d = self.expertSlice(slicelist)
#     752         squeeze = keys.get('squeeze', 0)
#     753         raw = keys.get('raw', 0)
#
# ~/anaconda2/envs/cdatpy3/lib/python3.6/site-packages/cdms2/fvariable.py in expertSlice(self, initslicelist)
#      92         if self.rank() == 0:
#      93             return self._obj_.getValue()
# ---> 94         result = self._obj_.getitem(*slist)
#      95
#      96         # If slices with negative strides were input, apply the appropriate
#
# OSError: NetCDF: HDF error
